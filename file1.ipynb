# %%
import cv2;

# %%
img = cv2.imread('jen.jpg', 0)
print(img)
# Out:
# [[255 255 255 ... 255 253 164]
#  [255 255 255 ... 255 253 164]
#  [255 255 255 ... 255 253 164]
#  ...
#  [167 168 170 ... 169 167 106]
#  [167 169 171 ... 170 168 107]
#  [167 170 172 ... 170 169 108]]

# %%
cv2.imshow('profile', img)
cv2.waitKey(20000)
cv2.destroyAllWindows()

# %%
k = 
if k == 27: 
    cv2.destroyAllWindows()
elif k == ord('s'): 
    cv2.imwrite('jen_copy.img', img)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 if k == 27:
#       2     cv2.destroyAllWindows()
#       3 elif k == ord('s'):
#       4     cv2.imwrite('jen_copy.img', img)
#
# NameError: name 'k' is not defined
