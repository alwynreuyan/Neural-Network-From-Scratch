# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

model.train(
    data="color_detection_custom.pt",
    epochs=300,
    device=0,
    imgsz=640,
    cache=True,
    val=True,
    patience=15
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.66 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.62  Python-3.10.8 torch-2.12.0+cu126
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 from ultralytics import YOLO
#       2 model = YOLO("yolo11n.pt")
# ----> 4 model.train(
#       5     data="color_detection_custom.pt",
#       6     epochs=300,
#       7     device=0,
#       8     imgsz=640,
#       9     cache=True,
#      10     val=True
#      11 )
#
# File C:\yolo\yolo\lib\site-packages\ultralytics\engine\model.py:783, in Model.train(self, trainer, **kwargs)
#     776             LOGGER.warning(
#     777                 f"model '{self.ckpt_path}' is not a resumable training checkpoint "
#     778                 f"(missing epoch/optimizer state). Use 'resume' only to continue incomplete training. "
# ...
